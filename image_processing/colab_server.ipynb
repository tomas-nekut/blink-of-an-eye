# %%
# INITIALIZATION
# %%shell
pip install face-recognition mediapipe forbiddenfruit fastapi nest-asyncio uvicorn
npm install -g localtunnel
cd /content
rm -R src
git clone https://github.com/tomas-nekut/in-the-wink-of-an-eye.git
mv in-the-wink-of-an-eye src

# %%
# RUNNING THE SERVER
# %%shell
PORT="8000"
URL="<IMAGE-PROCESSING SERVER URL>"
cd /content/src/image_processing
lt --port $PORT --subdomain $URL &
python server.py --port $PORT &
wait
